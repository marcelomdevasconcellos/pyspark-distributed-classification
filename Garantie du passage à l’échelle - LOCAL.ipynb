# %%
import pandas as pd
from spark_session import LocalSparkSession
from dataset import Dataset
from mr_id3 import MapReduceIDR3
from pyspark.mllib.tree import DecisionTree

# %%
from log import log
from sklearn.impute import SimpleImputer
from pyspark.sql.functions import lit
from pyspark.sql.functions import col, sum
from pyspark.sql.functions import udf, col
from pyspark.sql.types import IntegerType
from pyspark.sql import SparkSession
from pyspark import SparkContext
from pyspark.mllib.tree import DecisionTree, DecisionTreeModel
from pyspark.mllib.util import MLUtils
from pyspark.mllib.regression import LabeledPoint
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, LongType
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import VectorAssembler

# %%
# %time
num_fields = [
    'age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
    'hours_per_week', ]

categorical_fields = [
    'workclass', 'education',
    'marital_status', 'occupation', 'relationship',
    'race', 'sex', 'native_country', ]
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.39 µs

# %%
# %time
target = 'label'
filename = 'dataset/adult.data'
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.63 µs

# %%
# %time
numbers_of_cores = [4, ]
dataset_sizes = list(range(1, 31))
metrics = []
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs

# %%
# %time
for number_of_cores in numbers_of_cores:

    spark = LocalSparkSession(number_of_cores)
    spark.start()

    dataset = Dataset(spark.spark, filename, num_fields, categorical_fields, target)
    dataset.load()
    dataset.one_hot_encode_categorical_fields()

    for dataset_size in dataset_sizes:
        df = dataset.multiply_dataset(dataset_size)

        mr_id3 = MapReduceIDR3(df)
        mr_id3.set_labeled_point()
        mr_id3.split()
        mr_id3.train()

        metric = mr_id3.get_metrics()
        metric['length_rows'] = df.count()
        metric['dataset_size'] = dataset_size
        metric['number_of_cores'] = number_of_cores
        metrics.append(metric)
        log(f"Metrics: Clusters {metric['number_of_cores']} - File size {metric['dataset_size']}x - Time {metric['time']} seconds")

    spark.stop()
# Out:
# 2022-10-15 19:07:04,686 [INFO] LocalSparkSession : Starting with 4 clusters
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.91 µs
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/10/15 19:07:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2022-10-15 19:07:08,989 [INFO] Dataset : Starting
# 2022-10-15 19:07:08,990 [INFO] Dataset : Loading Dataset dataset/adult.data
# 2022-10-15 19:07:12,596 [INFO] Dataset : One Hot Encode Categorical Fields
# 2022-10-15 19:07:20,906 [INFO] Dataset : Multiplying Dataset by 1x
# 2022-10-15 19:07:21,071 [INFO] MapReduceIDR3 : Starting
# 2022-10-15 19:07:21,073 [INFO] MapReduceIDR3 : Setting Labeled Point
# 2022-10-15 19:07:21,669 [INFO] MapReduceIDR3 : Splitting
# 2022-10-15 19:07:21,670 [INFO] MapReduceIDR3 : Training
# 2022-10-15 19:07:26,351 [INFO] MapReduceIDR3 : Training time 4.679731 seconds
# 2022-10-15 19:07:26,352 [INFO] MapReduceIDR3 : Get metrics
# 2022-10-15 19:07:26,893 [INFO] Metrics: Clusters 4 - File size 1x - Time 4.679731 seconds
# 2022-10-15 19:07:26,896 [INFO] Dataset : Multiplying Dataset by 2x
# 2022-10-15 19:07:27,114 [INFO] MapReduceIDR3 : Starting
# 2022-10-15 19:07:27,117 [INFO] MapReduceIDR3 : Setting Labeled Point
# 2022-10-15 19:07:27,458 [INFO] MapReduceIDR3 : Splitting
# 2022-10-15 19:07:27,462 [INFO] MapReduceIDR3 : Training
# 2022-10-15 19:07:30,182 [INFO] MapReduceIDR3 : Training time 2.719242 seconds
# 2022-10-15 19:07:30,185 [INFO] MapReduceIDR3 : Get metrics
# 2022-10-15 19:07:30,518 [INFO] Metrics: Clusters 4 - File size 2x - Time 2.719242 seconds
# 2022-10-15 19:07:30,520 [INFO] Dataset : Multiplying Dataset by 3x
# 2022-10-15 19:07:30,735 [INFO] MapReduceIDR3 : Starting
# 2022-10-15 19
[INFO] MapReduceIDR3 : Starting
# 2022-10-15 19:10:18,227 [INFO] MapReduceIDR3 : Setting Labeled Point
# 2022-10-15 19:10:19,815 [INFO] MapReduceIDR3 : Splitting
# 2022-10-15 19:10:19,817 [INFO] MapReduceIDR3 : Training
# 2022-10-15 19:10:27,211 [INFO] MapReduceIDR3 : Training time 7.390246 seconds
# 2022-10-15 19:10:27,213 [INFO] MapReduceIDR3 : Get metrics
# 2022-10-15 19:10:28,799 [INFO] Metrics: Clusters 4 - File size 27x - Time 7.390246 seconds
# 2022-10-15 19:10:28,802 [INFO] Dataset : Multiplying Dataset by 28x
# 2022-10-15 19:10:31,536 [INFO] MapReduceIDR3 : Starting
# 2022-10-15 19:10:31,538 [INFO] MapReduceIDR3 : Setting Labeled Point
# 2022-10-15 19:10:33,226 [INFO] MapReduceIDR3 : Splitting
# 2022-10-15 19:10:33,228 [INFO] MapReduceIDR3 : Training
# 2022-10-15 19:10:39,814 [INFO] MapReduceIDR3 : Training time 6.585159 seconds
# 2022-10-15 19:10:39,816 [INFO] MapReduceIDR3 : Get metrics
# 2022-10-15 19:10:41,121 [INFO] Metrics: Clusters 4 - File size 28x - Time 6.585159 seconds
# 2022-10-15 19:10:41,122 [INFO] Dataset : Multiplying Dataset by 29x
# 2022-10-15 19:10:43,672 [INFO] MapReduceIDR3 : Starting
# 2022-10-15 19:10:43,674 [INFO] MapReduceIDR3 : Setting Labeled Point
# 2022-10-15 19:10:45,350 [INFO] MapReduceIDR3 : Splitting
# 2022-10-15 19:10:45,351 [INFO] MapReduceIDR3 : Training
# 2022-10-15 19:10:52,794 [INFO] MapReduceIDR3 : Training time 7.441605 seconds
# 2022-10-15 19:10:52,796 [INFO] MapReduceIDR3 : Get metrics
# 2022-10-15 19:10:54,172 [INFO] Metrics: Clusters 4 - File size 29x - Time 7.441605 seconds
# 2022-10-15 19:10:54,174 [INFO] Dataset : Multiplying Dataset by 30x
# 2022-10-15 19:10:56,843 [INFO] MapReduceIDR3 : Starting
# 2022-10-15 19:10:56,845 [INFO] MapReduceIDR3 : Setting Labeled Point
# 2022-10-15 19:10:58,791 [INFO] MapReduceIDR3 : Splitting
# 2022-10-15 19:10:58,793 [INFO] MapReduceIDR3 : Training
# 2022-10-15 19:11:05,997 [INFO] MapReduceIDR3 : Training time 7.202682 seconds
# 2022-10-15 19:11:05,998 [INFO] MapReduceIDR3 : Get metrics
# 2022-10-15 19:11:07,303 [INFO] Metrics: Clusters 4 - File size 30x - Time 7.202682 seconds
# 2022-10-15 19:11:07,304 [INFO] LocalSparkSession : Stopping

# %%
# %time
df = pd.DataFrame.from_dict(metrics)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs

# %%
df
# Out:
#         time  length_rows  m_factor  n_cores
# 0   4.679731          800         1        4
# 1   2.719242         1200         2        4
# 2   2.296706         1600         3        4
# 3   2.485174         2000         4        4
# 4   2.282335         2400         5        4
# 5   2.744761         2800         6        4
# 6   2.442164         3200         7        4
# 7   2.788682         3600         8        4
# 8   3.235650         4000         9        4
# 9   2.966792         4400        10        4
# 10  2.760167         4800        11        4
# 11  3.430516         5200        12        4
# 12  3.205853         5600        13        4
# 13  3.821062         6000        14        4
# 14  4.011995         6400        15        4
# 15  3.766223         6800        16        4
# 16  4.325318         7200        17        4
# 17  4.317629         7600        18        4
# 18  4.994879         8000        19        4
# 19  5.155238         8400        20        4
# 20  5.502024         8800        21        4
# 21  6.999862         9200        22        4
# 22  6.218585         9600        23        4
# 23  6.469181        10000        24        4
# 24  6.974109        10400        25        4
# 25  7.477665        10800        26        4
# 26  7.390246        11200        27        4
# 27  6.585159        11600        28        4
# 28  7.441605        12000        29        4
# 29  7.202682        12400        30        4

# %%
# %time
df[['m_factor', 'time']].plot()
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.63 µs
# <AxesSubplot: >
