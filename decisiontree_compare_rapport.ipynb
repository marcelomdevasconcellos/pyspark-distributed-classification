# %% [markdown]
# # Comparaison avec scikit-learn (python) et MLlib (pyspark)
#
# ## CLOUD

# %%
import pandas as pd

# %%
df = pd.read_csv('results/Decisiontree_compare_CLOUD_32_CORES.csv')
df = df.drop(columns=['Unnamed: 0', 'dataset_size_num'])
df['dataset_size'] = df['dataset_size']/100000000
df = df.round(4)
df
# Out:
#    dataset_size  pyspark_time  pyspark_train_time  pyspark_predict_time  \
# 0        3.6064        9.3077              9.2882                0.0195
# 1        7.2129       13.8471             13.8299                0.0172
# 2       10.8193       20.5202             20.5041                0.0160
# 3       14.4257       26.4062             26.3913                0.0149
# 4       18.0322       34.0198             34.0047                0.0151
# 5       21.6386       39.0455             39.0290                0.0165
# 6       25.2450       47.0292             47.0107                0.0185
# 7       28.8514       52.4215             52.4038                0.0177
# 8       32.4579       57.1572             57.1434                0.0138
# 9       36.0643       63.7693             63.7549                0.0145
#
#    sklearn_time  sklearn_train_time  sklearn_predict_time
# 0        4.8605              4.7474                0.1131
# 1       12.3286             12.0859                0.2427
# 2       19.8822             19.4906                0.3915
# 3       28.1720             27.6649                0.5071
# 4       37.1242             36.4931                0.6311
# 5       47.0924             46.3083                0.7841
# 6       56.4024             55.4575                0.9449
# 7       65.1727             64.1710                1.0017
# 8       75.7063             74.5154                1.1908
# 9       84.9322             83.6269                1.3053

# %%
dftemp = df[['pyspark_train_time', 'sklearn_train_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', "Dataset Size (GB)"]
dftemp.plot.line(
    x="Dataset Size (GB)", 
    xlabel="Dataset Size (GB)",
    ylabel="Training time (s)",
    rot=0, 
    title='DecisionTree algorithm training time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm training time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Training time (s)'>

# %%
dftemp = df[['pyspark_predict_time', 'sklearn_predict_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', 'dataset_size']
dftemp.plot.line(
    x='dataset_size', 
    xlabel="Dataset Size (GB)",
    ylabel="Predict time (s)",
    rot=0, 
    title='DecisionTree algorithm prediction time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm prediction time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Predict time (s)'>

# %%
dftemp = df[['pyspark_time', 'sklearn_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', 'dataset_size']
dftemp.plot.line(
    x='dataset_size', 
    xlabel="Dataset Size (GB)",
    ylabel="Total time including training and prediction (s)",
    rot=0, 
    title='DecisionTree algorithm execution time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm execution time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Total time including training and prediction (s)'>

# %%
dftemp1 = df
dftemp1.columns = ['Dataset Size (GB)', 'PySpark Total time (s)', 'PySpark Training time (s)',
       'PySpark Predict time (s)', 'Sklearn Total time (s)', 'Sklearn Training time (s)',
       'Sklearn Predict time (s)']
dftemp1
# Out:
#    Dataset Size (GB)  PySpark Total time (s)  PySpark Training time (s)  \
# 0             3.6064                  9.3077                     9.2882
# 1             7.2129                 13.8471                    13.8299
# 2            10.8193                 20.5202                    20.5041
# 3            14.4257                 26.4062                    26.3913
# 4            18.0322                 34.0198                    34.0047
# 5            21.6386                 39.0455                    39.0290
# 6            25.2450                 47.0292                    47.0107
# 7            28.8514                 52.4215                    52.4038
# 8            32.4579                 57.1572                    57.1434
# 9            36.0643                 63.7693                    63.7549
#
#    PySpark Predict time (s)  Sklearn Total time (s)  \
# 0                    0.0195                  4.8605
# 1                    0.0172                 12.3286
# 2                    0.0160                 19.8822
# 3                    0.0149                 28.1720
# 4                    0.0151                 37.1242
# 5                    0.0165                 47.0924
# 6                    0.0185                 56.4024
# 7                    0.0177                 65.1727
# 8                    0.0138                 75.7063
# 9                    0.0145                 84.9322
#
#    Sklearn Training time (s)  Sklearn Predict time (s)
# 0                     4.7474                    0.1131
# 1                    12.0859                    0.2427
# 2                    19.4906                    0.3915
# 3                    27.6649                    0.5071
# 4                    36.4931                    0.6311
# 5                    46.3083                    0.7841
# 6                    55.4575                    0.9449
# 7                    64.1710                    1.0017
# 8                    74.5154                    1.1908
# 9                    83.6269                    1.3053

# %% [markdown]
# ## LOCAL

# %%
df = pd.read_csv('results/Decisiontree_compare_LOCAL_4_CORES.csv')
df = df.drop(columns=['Unnamed: 0', 'dataset_size_num'])
df['dataset_size'] = df['dataset_size']/100000000
df = df.round(4)
df
# Out:
#     dataset_size  pyspark_time  pyspark_train_time  pyspark_predict_time  \
# 0         0.0361        6.0357              6.0022                0.0334
# 1         0.3606        7.3158              7.2914                0.0244
# 2         0.7213        9.3482              9.3196                0.0286
# 3         1.0819       12.4715             12.4479                0.0236
# 4         1.4426       13.2636             13.2455                0.0180
# 5         1.8032       15.7827             15.7658                0.0169
# 6         2.1639       19.0085             18.9951                0.0134
# 7         2.5245       21.9387             21.9207                0.0180
# 8         2.8851       25.5647             25.5482                0.0164
# 9         3.2458       33.4645             33.4438                0.0207
# 10        3.6064       37.7745             37.7562                0.0182
#
#     sklearn_time  sklearn_train_time  sklearn_predict_time
# 0         0.0432              0.0400                0.0032
# 1         0.4872              0.4758                0.0114
# 2         1.0791              1.0562                0.0229
# 3         1.9206              1.8903                0.0302
# 4         2.2291              2.1930                0.0361
# 5         3.1941              3.1366                0.0575
# 6         3.6897              3.6303                0.0594
# 7         4.5877              4.5180                0.0697
# 8         5.4478              5.3697                0.0781
# 9         7.6003              7.5116                0.0887
# 10        7.5984              7.5043                0.0941

# %%
dftemp = df[['pyspark_train_time', 'sklearn_train_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', "Dataset Size (GB)"]
dftemp.plot.line(
    x="Dataset Size (GB)", 
    xlabel="Dataset Size (GB)",
    ylabel="Training time (s)",
    rot=0, 
    title='DecisionTree algorithm training time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm training time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Training time (s)'>

# %%
dftemp = df[['pyspark_predict_time', 'sklearn_predict_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', 'dataset_size']
dftemp.plot.line(
    x='dataset_size', 
    xlabel="Dataset Size (GB)",
    ylabel="Predict time (s)",
    rot=0, 
    title='DecisionTree algorithm prediction time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm prediction time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Predict time (s)'>

# %%
dftemp = df[['pyspark_time', 'sklearn_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', 'dataset_size']
dftemp.plot.line(
    x='dataset_size', 
    xlabel="Dataset Size (GB)",
    ylabel="Total time including training and prediction (s)",
    rot=0, 
    title='DecisionTree algorithm execution time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm execution time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Total time including training and prediction (s)'>

# %%
dftemp1 = df
dftemp1.columns = ['Dataset Size (GB)', 'PySpark Total time (s)', 'PySpark Training time (s)',
       'PySpark Predict time (s)', 'Sklearn Total time (s)', 'Sklearn Training time (s)',
       'Sklearn Predict time (s)']
dftemp1
# Out:
#     Dataset Size (GB)  PySpark Total time (s)  PySpark Training time (s)  \
# 0              0.0361                  6.0357                     6.0022
# 1              0.3606                  7.3158                     7.2914
# 2              0.7213                  9.3482                     9.3196
# 3              1.0819                 12.4715                    12.4479
# 4              1.4426                 13.2636                    13.2455
# 5              1.8032                 15.7827                    15.7658
# 6              2.1639                 19.0085                    18.9951
# 7              2.5245                 21.9387                    21.9207
# 8              2.8851                 25.5647                    25.5482
# 9              3.2458                 33.4645                    33.4438
# 10             3.6064                 37.7745                    37.7562
#
#     PySpark Predict time (s)  Sklearn Total time (s)  \
# 0                     0.0334                  0.0432
# 1                     0.0244                  0.4872
# 2                     0.0286                  1.0791
# 3                     0.0236                  1.9206
# 4                     0.0180                  2.2291
# 5                     0.0169                  3.1941
# 6                     0.0134                  3.6897
# 7                     0.0180                  4.5877
# 8                     0.0164                  5.4478
# 9                     0.0207                  7.6003
# 10                    0.0182                  7.5984
#
#     Sklearn Training time (s)  Sklearn Predict time (s)
# 0                      0.0400                    0.0032
# 1                      0.4758                    0.0114
# 2                      1.0562                    0.0229
# 3                      1.8903                    0.0302
# 4                      2.1930                    0.0361
# 5                      3.1366                    0.0575
# 6                      3.6303                    0.0594
# 7                      4.5180                    0.0697
# 8                      5.3697                    0.0781
# 9                      7.5116                    0.0887
# 10                     7.5043                    0.0941

# %% [markdown]
# ## DOCKER

# %%
df = pd.read_csv('results/Decisiontree_compare_DOCKER_4_CORES.csv')
df = df.drop(columns=['Unnamed: 0', 'dataset_size_num'])
df['dataset_size'] = df['dataset_size']/100000000
df = df.round(4)
df
# Out:
#     dataset_size  pyspark_time  pyspark_train_time  pyspark_predict_time  \
# 0         0.0361        5.3426              5.3043                0.0383
# 1         0.3606        5.6113              5.5897                0.0215
# 2         0.7213        7.0916              7.0651                0.0266
# 3         1.0819        9.7278              9.7052                0.0225
# 4         1.4426       12.5738             12.5504                0.0234
# 5         1.8032       15.3593             15.3361                0.0232
# 6         2.1639       17.8924             17.8754                0.0170
# 7         2.5245       20.5641             20.5427                0.0214
# 8         2.8851       23.6886             23.6706                0.0179
# 9         3.2458       25.9775             25.9619                0.0157
# 10        3.6064       29.0025             28.9832                0.0193
#
#     sklearn_time  sklearn_train_time  sklearn_predict_time
# 0         0.0494              0.0440                0.0054
# 1         0.4922              0.4818                0.0104
# 2         1.1035              1.0841                0.0194
# 3         1.8640              1.8366                0.0274
# 4         2.7316              2.6960                0.0355
# 5         3.6348              3.5916                0.0432
# 6         4.6377              4.5768                0.0609
# 7         5.2897              5.2195                0.0702
# 8         6.1374              6.0570                0.0804
# 9         7.3477              7.2563                0.0914
# 10        8.3321              8.2297                0.1025

# %%
dftemp = df[['pyspark_train_time', 'sklearn_train_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', "Dataset Size (GB)"]
dftemp.plot.line(
    x="Dataset Size (GB)", 
    xlabel="Dataset Size (GB)",
    ylabel="Training time (s)",
    rot=0, 
    title='DecisionTree algorithm training time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm training time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Training time (s)'>

# %%
dftemp = df[['pyspark_predict_time', 'sklearn_predict_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', 'dataset_size']
dftemp.plot.line(
    x='dataset_size', 
    xlabel="Dataset Size (GB)",
    ylabel="Predict time (s)",
    rot=0, 
    title='DecisionTree algorithm prediction time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm prediction time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Predict time (s)'>

# %%
dftemp = df[['pyspark_time', 'sklearn_time', 'dataset_size']]
dftemp.columns=['pyspark', 'sklearn', 'dataset_size']
dftemp.plot.line(
    x='dataset_size', 
    xlabel="Dataset Size (GB)",
    ylabel="Total time including training and prediction (s)",
    rot=0, 
    title='DecisionTree algorithm execution time comparison between pyspark and sklearn', 
    figsize=(15,10), 
    fontsize=12)
# Out:
# <AxesSubplot:title={'center':'DecisionTree algorithm execution time comparison between pyspark and sklearn'}, xlabel='Dataset Size (GB)', ylabel='Total time including training and prediction (s)'>

# %%
dftemp1 = df
dftemp1.columns = ['Dataset Size (GB)', 'PySpark Total time (s)', 'PySpark Training time (s)',
       'PySpark Predict time (s)', 'Sklearn Total time (s)', 'Sklearn Training time (s)',
       'Sklearn Predict time (s)']
dftemp1
# Out:
#     Dataset Size (GB)  PySpark Total time (s)  PySpark Training time (s)  \
# 0              0.0361                  5.3426                     5.3043
# 1              0.3606                  5.6113                     5.5897
# 2              0.7213                  7.0916                     7.0651
# 3              1.0819                  9.7278                     9.7052
# 4              1.4426                 12.5738                    12.5504
# 5              1.8032                 15.3593                    15.3361
# 6              2.1639                 17.8924                    17.8754
# 7              2.5245                 20.5641                    20.5427
# 8              2.8851                 23.6886                    23.6706
# 9              3.2458                 25.9775                    25.9619
# 10             3.6064                 29.0025                    28.9832
#
#     PySpark Predict time (s)  Sklearn Total time (s)  \
# 0                     0.0383                  0.0494
# 1                     0.0215                  0.4922
# 2                     0.0266                  1.1035
# 3                     0.0225                  1.8640
# 4                     0.0234                  2.7316
# 5                     0.0232                  3.6348
# 6                     0.0170                  4.6377
# 7                     0.0214                  5.2897
# 8                     0.0179                  6.1374
# 9                     0.0157                  7.3477
# 10                    0.0193                  8.3321
#
#     Sklearn Training time (s)  Sklearn Predict time (s)
# 0                      0.0440                    0.0054
# 1                      0.4818                    0.0104
# 2                      1.0841                    0.0194
# 3                      1.8366                    0.0274
# 4                      2.6960                    0.0355
# 5                      3.5916                    0.0432
# 6                      4.5768                    0.0609
# 7                      5.2195                    0.0702
# 8                      6.0570                    0.0804
# 9                      7.2563                    0.0914
# 10                     8.2297                    0.1025
